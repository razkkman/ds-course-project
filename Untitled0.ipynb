# %% [markdown]
# <a href="https://colab.research.google.com/github/razkkman/ds-course-project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
print("Commit.")
# Out:
# Hello World!
# Commit.
